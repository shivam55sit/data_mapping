# %%
import pandas as pd

pd.set_option("Display.max_columns",None)

# %%
df = pd.read_excel(r"C:\Users\shivam.prajapati\Desktop\Harshitha\Vishwa Bharathi, Excel.xlsx", header=1)

# %%
df.head()
# Out:
#    State code  District code:  Mandal code:  Village code:  School code:  \
# 0           1               5             1              1             3
# 1           1               5             1              1             3
# 2           1               5             1              1             3
# 3           1               5             1              1             3
# 4           1               5             1              1             3
#
#        School Name   Class id:  Class   Section  Child no.         Subject ID  \
# 0  Vishwa Bharathi         101       1        1          1  15010100301010001
# 1  Vishwa Bharathi         101       1        1          2  15010100301010002
# 2  Vishwa Bharathi         101       1        1          3  15010100301010003
# 3  Vishwa Bharathi         101       1        1          4  15010100301010004
# 4  Vishwa Bharathi         101       1        1          5  15010100301010005
#
# ...

# %%
df.columns
# Out:
# Index(['State code', 'District code:', 'Mandal code:', 'Village code:',
#        'School code:', 'School Name ', 'Class id:', 'Class ', 'Section',
#        'Child no.', 'Subject ID', 'Parent Consent (Yes/No)',
#        'Name of the child \n(with surname)', 'Father/Guardian Name',
#        'Mobile number', 'Available \n(1=Yes;0=No)', 'Age \n(Completed Years)',
#        'Gender\n(0: Male, 1: Female)', 'Any disability*\n (use codes)',
#        'Using glasses? \n(Yes: 1; No: 1)',
#        'Vision test Right Eye \n(0=Pass, 1=Fail, -99=Unable)',
#        'Vision test Left Eye \n(0= Pass, 1=Fail, -99=Unable)',
#        'Signs & Symptoms  ', 'Referral*(0=No; 1=Yes)',
#        'Reason for Referral,\n     Specify reason'],
#       dtype='str')
